# %% [markdown]
# <a href="https://colab.research.google.com/github/Eugene1617/Eugene1617/blob/main/fashion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
342
# Out:
# 342

# %%
import torch
from torch import nn
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
train=FashionMNIST(
    train=True,
    download=True,
    transform=ToTensor(),
    root='data'
)
test=FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)
class modelclass(nn.Module):
    def __init__(self):
       super().__init__()
       self.flat=nn.Flatten()
       self.linear_ru=nn.Sequential(
           nn.Linear(28*28,512),
           nn.ReLU(),
           nn.Linear(512,10)
       )
    def forwad(self,x):
      x=self.flat(x)
      x=self.linear_ru(x)
      return x
train_loader = DataLoader(train, batch_size=64, shuffle=True)
test_loader = DataLoader(test, batch_size=64)
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
model=modelclass().to(device)
epoch=5
lossfn=nn.CrossEntropyLoss()
optimizer=optim.Adam(model.parameters(),lr=0.01)
for x in range (epoch):
  model.train()

# %%
import torch
from torch import nn
import torch.optim as optim
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from PIL import Image
import requests
from io import BytesIO
from torchvision import transforms
import torch
import time

# URL of the image
url = 'https://media.istockphoto.com/id/2216380543/photo/minimalist-white.webp?a=1&b=1&s=612x612&w=0&k=20&c=1PrJHsoxtlGV4Ts5f3w4y3-k5j2V7GYFMUcWNhWO6EI='  # replace with your image URL
response = requests.get(url)
img = Image.open(BytesIO(response.content)).convert('L')  # convert to grayscale

# Preprocess: resize to 28x28 and normalize
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

img_tensor = transform(img).unsqueeze(0)  # add batch dimension
img_tensor = img_tensor.to(device)        # move to GPU if available
# Datasets
train = FashionMNIST(root='data', train=True, download=True, transform=ToTensor())
test = FashionMNIST(root='data', train=False, download=True, transform=ToTensor())

# DataLoaders
train_loader = DataLoader(train, batch_size=64, shuffle=True)
test_loader = DataLoader(test, batch_size=64)
# After opening the image:


img = Image.open(BytesIO(response.content)).convert('L')  # grayscale
img = img.resize((28,28))
 img = ImageOps.invert(img)
img_tensor = transforms.ToTensor()(img)
img_tensor = (img_tensor - 0.5)/0.5  # same normalization as training
img_tensor = img_tensor.unsqueeze(0).to(device)
# Model
class ModelClass(nn.Module):
    def __init__(self):
        super().__init__()
        self.flat = nn.Flatten()
        self.linear_ru = nn.Sequential(
            nn.Linear(28*28, 512),

            nn.ReLU(),
             nn.Linear( 512,256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )
    def forward(self, x):
        x = self.flat(x)
        x = self.linear_ru(x)
        return x

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ModelClass().to(device)

# Loss and optimizer
lossfn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 10
for e in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = lossfn(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {e+1}/{epochs}, Loss: {epoch_loss:.4f}")
model.eval()  # evaluation mode
running_loss = 0.0
correct = 0
total = 0

model.eval()  # make sure model is in eval mode
with torch.no_grad():
    outputs = model(img_tensor)
    _, predicted = torch.max(outputs, 1)

# FashionMNIST class names
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
           'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print("Predicted class:", classes[predicted.item()])

print(f"Test Loss: {epoch_loss:.4f}, Test Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/10, Loss: 0.6116
# Epoch 2/10, Loss: 0.4177
# Epoch 3/10, Loss: 0.3766
# Epoch 4/10, Loss: 0.3494
# Epoch 5/10, Loss: 0.3267
# Epoch 6/10, Loss: 0.3113
# Epoch 7/10, Loss: 0.2978
# Epoch 8/10, Loss: 0.2838
# Epoch 9/10, Loss: 0.2728
# Epoch 10/10, Loss: 0.2633
# Predicted class: Bag
# Test Loss: 0.2633, Test Accuracy: 88.04%

# %%
import torch
from torch import nn
import torch.optim as optim
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from PIL import Image
import requests
from io import BytesIO
from torchvision import transforms
import torch
import time

# URL of the image
url = 'https://media.istockphoto.com/id/2216380543/photo/minimalist-white.webp?a=1&b=1&s=612x612&w=0&k=20&c=1PrJHsoxtlGV4Ts5f3w4y3-k5j2V7GYFMUcWNhWO6EI='  # replace with your image URL
response = requests.get(url)
img = Image.open(BytesIO(response.content)).convert('L')  # convert to grayscale

# Preprocess: resize to 28x28 and normalize
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

img_tensor = transform(img).unsqueeze(0)  # add batch dimension
img_tensor = img_tensor.to(device)        # move to GPU if available
# Datasets
train = FashionMNIST(root='data', train=True, download=True, transform=ToTensor())
test = FashionMNIST(root='data', train=False, download=True, transform=ToTensor())

# DataLoaders
train_loader = DataLoader(train, batch_size=64, shuffle=True)
test_loader = DataLoader(test, batch_size=64)
# After opening the image:


img = Image.open(BytesIO(response.content)).convert('L')  # grayscale
img = img.resize((28,28))
 img = ImageOps.invert(img)
img_tensor = transforms.ToTensor()(img)
img_tensor = (img_tensor - 0.5)/0.5  # same normalization as training
img_tensor = img_tensor.unsqueeze(0).to(device)
# Model
class ModelClass(nn.Module):
    def __init__(self):
        super().__init__()
        self.flat = nn.Flatten()
        self.linear_ru = nn.Sequential(
            nn.Linear(28*28, 512),

            nn.ReLU(),
             nn.Linear( 512,256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )
    def forward(self, x):
        x = self.flat(x)
        x = self.linear_ru(x)
        return x

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ModelClass().to(device)

# Loss and optimizer
lossfn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 10
for e in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = lossfn(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {e+1}/{epochs}, Loss: {epoch_loss:.4f}")
model.eval()  # evaluation mode
running_loss = 0.0
correct = 0
total = 0

model.eval()  # make sure model is in eval mode
with torch.no_grad():
    outputs = model(img_tensor)
    _, predicted = torch.max(outputs, 1)

# FashionMNIST class names
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
           'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print("Predicted class:", classes[predicted.item()])

print(f"Test Loss: {epoch_loss:.4f}, Test Accuracy: {accuracy:.2f}%")
